# %%
import ee
import geopandas as gpd
# from shapely.geometry import mapping
from os.path import exists
from unidecode import unidecode
import json
import concurrent.futures
import pandas as pd

# Trigger the authentication flow.
ee.Authenticate(quiet=True)
# Initialize the library.
ee.Initialize(project='ee-daytime-images')

# %%
df = gpd.read_file('../../dataset/favelas_urban_communities/fcu_blank/qg_2022_670_fcu_agreg.shp')
geojson = json.loads(df.to_json())
df
# Out:
#             cd_fcu                                       nm_fcu cd_uf  \
# 0      35503080069                              Jardim Miliunas    35
# 1      42024040016                                Rua Araranguá    42
# 2      33045570554                                        Tiqui    33
# 3      33045570104                Parque Nossa Senhora da Penha    33
# 4      35095020135  Núcleo Residencial Jardim das Andorinhas II    35
# ...            ...                                          ...   ...
# 12343  27043020123                              Vila Santa Cruz    27
# 12344  28003080047                         Invasão da Jabotiana    28
# 12345  35188000223                         Residencial Bambi II    35
# 12346  26116060881                              Sítio Wanderley    26
# 12347  24080030010                                  Resistência    24
#
#                      nm_uf sigla_uf   cd_mun          nm_mun  \
# 0                São Paulo       SP  3550308       São Paulo
# 1           Santa Catarina       SC  4202404        Blumenau
# 2           Rio de Janeiro       RJ  3304557  Rio de Janeiro
# 3           Rio de Janeiro       RJ  3304557  Rio de Janeiro
# 4                São Paulo       SP  3509502        Campinas
# ...                    ...      ...      ...             ...
# 12343              Alagoas       AL  2704302          Maceió
# 12344              Sergipe       SE  2800308         Aracaju
# 12345            São Paulo       SP  3518800       Guarulhos
# 12346           Pernambuco       PE  2611606          Recife
# 12347  Rio Grande do Norte       RN  2408003         Mossoró
#
#                                                 geometry
# 0      POLYGON ((-46.37112 -23.5, -46.37141 -23.5001,...
# 1      POLYGON ((-49.05007 -26.93529, -49.05009 -26.9...
# 2      POLYGON ((-43.48263 -22.8887, -43.48252 -22.88...
# 3      POLYGON ((-43.21664 -22.87497, -43.21662 -22.8...
# 4      POLYGON ((-47.01387 -22.91975, -47.01458 -22.9...
# ...                                                  ...
# 12343  POLYGON ((-35.76558 -9.57082, -35.76767 -9.572...
# 12344  POLYGON ((-37.08826 -10.94031, -37.08824 -10.9...
# 12345  POLYGON ((-46.39452 -23.37916, -46.3949 -23.37...
# 12346  POLYGON ((-34.95091 -8.04458, -34.95088 -8.044...
# 12347  POLYGON ((-37.34702 -5.14423, -37.34723 -5.145...
#
# [12348 rows x 8 columns]

# %%
so2_collection = (ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_SO2')
    .select('SO2_column_number_density')
    .filterDate('2024-01-01', '2024-11-01'))
so2_image = so2_collection.mean()

co_collection = (ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_CO')
    .select('CO_column_number_density')
    .filterDate('2024-01-01', '2024-11-01'))
co_image = co_collection.mean()

o3_collection = (ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3')
    .select('O3_column_number_density')
    .filterDate('2024-01-01', '2024-11-01'))
o3_image = o3_collection.mean()

no2_collection = (ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_NO2')
    .select('NO2_column_number_density')
    .filterDate('2024-01-01', '2024-11-01'))
no2_image = no2_collection.mean()

# %%
def get_mean(geometry, image, band_name):
    mean_value = image.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=geometry,
        scale=30,  # Adjust the scale according to your needs
        bestEffort=True
    ).get(band_name)
    return mean_value.getInfo()

# %%
def process_row(i, row):
    print(i)
    """Processa uma única linha do DataFrame."""
    try:
        geometry = ee.Geometry(row.geometry.__geo_interface__)  # Convert to GeoJSON format for Earth Engine
        so2_mean = get_mean(geometry, so2_image, 'SO2_column_number_density')
        co_mean = get_mean(geometry, co_image, 'CO_column_number_density')
        o3_mean = get_mean(geometry, o3_image, 'O3_column_number_density')
        no2_mean = get_mean(geometry, no2_image, 'NO2_column_number_density')

        # return i, so2_mean, co_mean, o3_mean, no2_mean
        df_result = pd.DataFrame([{
            "id": i,
            "SO2_mean": so2_mean,
            "CO_mean": co_mean,
            "O3_mean": o3_mean,
            "NO2_mean": no2_mean
        }])

        # Save individual CSV
        file_path = f"../../dataset/air_pollution/results/result_{i}.csv"
        df_result.to_csv(file_path, index=False)
    except Exception as e:
        print(f"Erro na linha {i}: {e}")
        return i, None, None, None, None

# %%
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    results = list(executor.map(lambda args: process_row(*args), enumerate(df.itertuples(index=False))))

# %%
# merge with df files 
for i in range(len(df)):
    file_path = f"../../dataset/air_pollution/results/result_{i}.csv"
    if exists(file_path):
        df_result = pd.read_csv(file_path)
        df.loc[i, 'SO2_mean'] = df_result['SO2_mean'].values[0]
        df.loc[i, 'CO_mean'] = df_result['CO_mean'].values[0]
        df.loc[i, 'O3_mean'] = df_result['O3_mean'].values[0]
        df.loc[i, 'NO2_mean'] = df_result['NO2_mean'].values[0]

df

# %%
df.to_file('../../dataset/air_pollution/air_pollution.shp')
